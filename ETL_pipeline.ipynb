# %% [markdown]
# # Introduction
#
# This notebook exemplifies the creation of a simple cloud data warehouse using AWS Redshift. An ETL process will define all queries needed to create a star schema for a Redshift database containing fact and dimension tables optimized for order analytics. The pipeline will use an Infrastructure as Code (IaC) approach to create, manage and tear down our AWS resources. A simple dashboard will demonstrate how similar workflows can support Online analytical processing (OLAP).
#
# Tools:
# - Pandas
# - Spark
# - S3
# - Redshift

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ### Imports

# %%
import os
import glob

import matplotlib
import pandas as pd
from pathlib import Path

# %% [markdown]
# Data for this project exists as .csv files within the "source_data" folder. So, before defining a database schema for analysis, we'll do some data exploration using pandas. The following cell prints of list of files within our source data directory.
#
# Our data is spread across six different files which include:
# - products.csv
# - orders.csv
# - order_products_train.csv
# - order_products_prior.csv
# - departments.csv
# - aisles.csv
#
# Next, we'll load each file as a dataframe, look at unique values, and review basic descriptive stats.

# %%
#### Get a list of file paths 

filepath = os.getcwd() + '/source_data'
for root, dirs, files in os.walk(filepath):
    for i in glob.glob(os.path.join(root,'*')):
        if i.endswith('.csv'):
            print(i)
#     print(file_path_list)
#     file_path_list = glob.glob(os.path.join(root,'*'))
#     print(file_path_list)
#     for fname in files:
#         print(fname.replace(".csv", "" ))
# Out:
# /Users/margiehenry/Projects/cloud_dw_from_csv/source_data/products/products.csv
# /Users/margiehenry/Projects/cloud_dw_from_csv/source_data/departments/departments.csv
# /Users/margiehenry/Projects/cloud_dw_from_csv/source_data/aisles/aisles.csv
# /Users/margiehenry/Projects/cloud_dw_from_csv/source_data/order_products/order_products__train.csv
# /Users/margiehenry/Projects/cloud_dw_from_csv/source_data/order_products/order_products__prior.csv
# /Users/margiehenry/Projects/cloud_dw_from_csv/source_data/orders/orders.csv

# %% [markdown]
# ### Products

# %%
products = pd.read_csv('/Users/margiehenry/Projects/cloud_dw_from_csv/source_data/products/products.csv')
products
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49683       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49684       49685                 En Croute Roast Hazelnut Cranberry
# 49685       49686                                   Artisan Baguette
# 49686       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49687       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id
# 0            61             19
# 1           104             13
# 2            94              7
# 3            38              1
# 4             5             13
# ...         ...            ...
# 49683       124              5
# 49684        42              1
# 49685       112              3
# 49686        41              8
# 49687        73             11
#
# [49688 rows x 4 columns]

# %%
products.nunique()
# Out:
# product_id       49688
# product_name     49688
# aisle_id           134
# department_id       21
# dtype: int64

# %%
products.describe()
# Out:
#          product_id      aisle_id  department_id
# count  49688.000000  49688.000000   49688.000000
# mean   24844.500000     67.769582      11.728687
# std    14343.834425     38.316162       5.850410
# min        1.000000      1.000000       1.000000
# 25%    12422.750000     35.000000       7.000000
# 50%    24844.500000     69.000000      13.000000
# 75%    37266.250000    100.000000      17.000000
# max    49688.000000    134.000000      21.000000

# %%
products.isna().sum()
# Out:
# product_id       0
# product_name     0
# aisle_id         0
# department_id    0
# dtype: int64

# %% [markdown]
# ### Departments

# %%
departments = pd.read_csv('/Users/margiehenry/Projects/cloud_dw_from_csv/source_data/departments/departments.csv')
departments.nunique()
# Out:
# department_id    21
# department       21
# dtype: int64

# %%
departments
# Out:
#     department_id       department
# 0               1           frozen
# 1               2            other
# 2               3           bakery
# 3               4          produce
# 4               5          alcohol
# 5               6    international
# 6               7        beverages
# 7               8             pets
# 8               9  dry goods pasta
# 9              10             bulk
# 10             11    personal care
# 11             12     meat seafood
# 12             13           pantry
# 13             14        breakfast
# 14             15     canned goods
# 15             16       dairy eggs
# 16             17        household
# 17             18           babies
# 18             19           snacks
# 19             20             deli
# 20             21          missing

# %%
departments.describe()
# Out:
#        department_id
# count      21.000000
# mean       11.000000
# std         6.204837
# min         1.000000
# 25%         6.000000
# 50%        11.000000
# 75%        16.000000
# max        21.000000

# %%
departments.isna().sum()
# Out:
# department_id    0
# department       0
# dtype: int64

# %% [markdown]
# ### Aisles

# %%
aisles = pd.read_csv('/Users/margiehenry/Projects/cloud_dw_from_csv/source_data/aisles/aisles.csv')
aisles.nunique()
# Out:
# aisle_id    134
# aisle       134
# dtype: int64

# %%
aisles
# Out:
#      aisle_id                       aisle
# 0           1       prepared soups salads
# 1           2           specialty cheeses
# 2           3         energy granola bars
# 3           4               instant foods
# 4           5  marinades meat preparation
# ..        ...                         ...
# 129       130    hot cereal pancake mixes
# 130       131                   dry pasta
# 131       132                      beauty
# 132       133  muscles joints pain relief
# 133       134  specialty wines champagnes
#
# [134 rows x 2 columns]

# %%
aisles.describe()
# Out:
#          aisle_id
# count  134.000000
# mean    67.500000
# std     38.826537
# min      1.000000
# 25%     34.250000
# 50%     67.500000
# 75%    100.750000
# max    134.000000

# %%
aisles.isna().sum()
# Out:
# aisle_id    0
# aisle       0
# dtype: int64

# %% [markdown]
# ## Using Spark for Large File Data Exploration
#
# Our orders data is somewhat large for pandas, and the orders_product data is split across files. I could use something like Dask to concatenate and work on these files. However, in this scenario I'll use Spark to explore the files and review some basic stats since we'll be using it again in later steps.

# %%
import pyspark
from pyspark import SparkConf
from pyspark.sql import SparkSession
from pyspark.sql.functions import countDistinct

sc = pyspark.SparkContext(appName="view_orders")
spark = SparkSession.builder.appName("testing").getOrCreate()

# spark.stop()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/01/09 19:32:39 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# ### Orders

# %%
orders = spark.read.option("header",True)\
    .csv('/Users/margiehenry/Projects/cloud_dw_from_csv/source_data/orders/orders.csv')

# %%
orders.printSchema()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- eval_set: string (nullable = true)
#  |-- order_number: string (nullable = true)
#  |-- order_dow: string (nullable = true)
#  |-- order_hour_of_day: string (nullable = true)
#  |-- days_since_prior_order: string (nullable = true)

# %%
orders.describe().show()
# Out:
# [Stage 1:====================================================>     (9 + 1) / 10]
# +-------+-----------------+------------------+--------+------------------+------------------+------------------+----------------------+
# |summary|         order_id|           user_id|eval_set|      order_number|         order_dow| order_hour_of_day|days_since_prior_order|
# +-------+-----------------+------------------+--------+------------------+------------------+------------------+----------------------+
# |  count|          3421083|           3421083| 3421083|           3421083|           3421083|           3421083|               3214874|
# |   mean|        1710542.0|102978.20805926077|    null|17.154857979183785|2.7762191095626734| 13.45201534134074|    11.114836226863012|
# | stddev|987581.7398225801| 59533.71779350224|    null|17.733164470966674| 2.046829193987996|4.2260884021020235|       9.2067365175338|
# |    min|                1|                 1|   prior|                 1|                 0|                00|                   0.0|
# |    max|           999999|             99999|   train|                99|                 6|                23|                   9.0|
# +-------+-----------------+------------------+--------+------------------+------------------+------------------+----------------------+

# %% [markdown]
# The 'eval_set' column is used for machine learning purposes, let's drop it for this project.

# %% [markdown]
# ## order_products_*

# %%
paths = ['/Users/margiehenry/Projects/cloud_dw_from_csv/source_data/order_products/order_products__prior.csv',
        '/Users/margiehenry/Projects/cloud_dw_from_csv/source_data/order_products/order_products__train.csv']

order_products = spark.read.options(header=True).csv(paths)

# %%
order_products.printSchema()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- product_id: string (nullable = true)
#  |-- add_to_cart_order: string (nullable = true)
#  |-- reordered: string (nullable = true)

# %%
order_products.describe().show()
# Out:
# +-------+-----------------+------------------+------------------+-------------------+
# |summary|         order_id|        product_id| add_to_cart_order|          reordered|
# +-------+-----------------+------------------+------------------+-------------------+
# |  count|         33819106|          33819106|          33819106|           33819106|
# |   mean|1710566.290919606|25575.514530129803| 8.367737574139305| 0.5900617242809434|
# | stddev|987400.7619328625|14097.696773864618|7.1395401151131015|0.49182201350891674|
# |    min|                1|                 1|                 1|                  0|
# |    max|           999999|              9999|                99|                  1|
# +-------+-----------------+------------------+------------------+-------------------+

# %% [markdown]
# How many distinct products were ordered?

# %%
# from pyspark.sql.functions import countDistinct

order_products2 = order_products.select(countDistinct("product_id"))
order_products2.show()
# Out:
# [Stage 27:=============================================>           (8 + 2) / 10]
# +--------------------------+
# |count(DISTINCT product_id)|
# +--------------------------+
# |                     49685|
# +--------------------------+

# %% [markdown]
# How many orders had product_id '49302' placed in the cart first?

# %%
#spark sql 

order_products.createOrReplaceTempView("order_in_cart")

spark.sql('''
    SELECT COUNT(order_id)
    FROM order_in_cart
    WHERE product_id = '49302'
    AND add_to_cart_order = '1'

''').show()
# Out:
# [Stage 72:=============================================>           (8 + 2) / 10]
# +---------------+
# |count(order_id)|
# +---------------+
# |             28|
# +---------------+

# %% [markdown]
# Select all order_ids where product_id 49302 was put in the cart first.

# %%
#df filtering 

order_products.select(['order_id','product_id','add_to_cart_order']).filter((order_products.product_id=='49302') &
                 (order_products.add_to_cart_order=='1')).show(100)
# Out:
# [Stage 97:=======================>                                  (2 + 3) / 5]
# +--------+----------+-----------------+
# |order_id|product_id|add_to_cart_order|
# +--------+----------+-----------------+
# |  262316|     49302|                1|
# |  269385|     49302|                1|
# |  312335|     49302|                1|
# |  316883|     49302|                1|
# |  584879|     49302|                1|
# |  683097|     49302|                1|
# |  691172|     49302|                1|
# |  809060|     49302|                1|
# | 1111504|     49302|                1|
# | 1140876|     49302|                1|
# | 1666866|     49302|                1|
# | 1714323|     49302|                1|
# | 2172185|     49302|                1|
# | 2355248|     49302|                1|
# | 2470870|     49302|                1|
# | 2494999|     49302|                1|
# | 2541372|     49302|                1|
# | 2553776|     49302|                1|
# | 2578428|     49302|                1|
# | 2787832|     49302|                1|
# | 2851180|     49302|                1|
# | 2861653|     49302|                1|
# | 2881567|     49302|                1|
# | 2938406|     49302|                1|
# | 2946792|     49302|                1|
# | 2982908|     49302|                1|
# |       1|     49302|                1|
# | 1242203|     49302|                1|
# +--------+----------+-----------------+
# [Stage 97:==============================================>           (4 + 1) / 5]

# %% [markdown]
# I can easily write the newly concatenated dataframe to a file of my choosen format with:
# ```
# dfname.write.save(out_path, format="format_name", header=True)
# ```
#
# This will results in file parts that can be easily used in downstream processes.

# %%
order_products.write.save('/Users/margiehenry/Projects/cloud_dw_from_csv/source_data/order_products_all', format="csv", header=True)

# %% [markdown]
# ## Investigating the relationship between departments and aisles.

# %% [markdown]
# Can a given aisle house products for many departments? To answer this question we will perform a join on the products, departments, and aisles dataframes and create a pivot table to visualize our results.

# %%
product_detailed = pd.merge(pd.merge(products,departments,on='department_id'),aisles,on='aisle_id')
product_detailed
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1              78                  Nutter Butter Cookie Bites Go-Pak
# 2             102                              Danish Butter Cookies
# 3             172     Gluten Free All Natural Chocolate Chip Cookies
# 4             285                       Mini Nilla Wafers Munch Pack
# ...           ...                                                ...
# 49683       22827                         Organic Black Mission Figs
# 49684       28655                         Crystallized Ginger Chunks
# 49685       30365                                    Vegetable Chips
# 49686       38007                     Naturally Sweet Plantain Chips
# 49687       48778  Fit Super A Juice, Cold Pressed, Carrot/Apple/...
#
#        aisle_id  department_id department                         aisle
# 0            61             19     snacks                 cookies cakes
# 1            61             19     snacks                 cookies cakes
# 2            61             19     snacks                 cookies cakes
# 3            61             19     snacks                 cookies cakes
# 4            61             19     snacks                 cookies cakes
# ...         ...            ...        ...                           ...
# 49683        18             10       bulk  bulk dried fruits vegetables
# 49684        18             10       bulk  bulk dried fruits vegetables
# 49685        18             10       bulk  bulk dried fruits vegetables
# 49686        18             10       bulk  bulk dried fruits vegetables
# 49687        18             10       bulk  bulk dried fruits vegetables
#
# [49688 rows x 6 columns]

# %% [markdown]
# Our pivot table summarizes the count of product_ids in each aisle by department. The resulting pivot tables reveals that a one-to-one relationship between "department" and "aisle" does not exists. The "babies" department, for example, is spread across the "baby accessories," "baby bath care," and "baby food formula" aisles.

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_row', None)


# product_detailed.groupby(['department_id', 'aisle_id']).agg({'product_id':'sum'})
product_detailed.pivot_table("product_id", index='aisle', columns='department')
# Out:
# department                          alcohol        babies        bakery  \
# aisle
# air fresheners candles                  NaN           NaN           NaN
# asian foods                             NaN           NaN           NaN
# baby accessories                        NaN  23793.113636           NaN
# baby bath body care                     NaN  23451.477273           NaN
# baby food formula                       NaN  25210.770195           NaN
# bakery desserts                         NaN           NaN  25824.383838
# baking ingredients                      NaN           NaN           NaN
# baking supplies decor                   NaN           NaN           NaN
# beauty                                  NaN           NaN           NaN
# beers coolers                  24662.241558           NaN           NaN
# body lotions soap                       NaN           NaN           NaN
# bread                                   NaN           NaN  24750.235189
# breakfast bakery                        NaN           NaN  26268.353982
# breakfast bars pastries                 NaN           NaN           NaN
# bulk dried fruits vegetables            NaN           NaN           NaN
# bulk grains rice dried goods            NaN           NaN           NaN
# buns rolls                              NaN           NaN  26323.169231
# butter                                  NaN           NaN           NaN
# candy chocolate                         NaN           NaN           NaN
# canned fruit applesauce                 NaN           NaN           NaN
# canned jarred vegetables                NaN           NaN           NaN
# canned meals beans                      NaN           NaN           NaN
# canned meat seafood                     NaN           NaN           NaN
# cat food care                           NaN           NaN           NaN
# cereal                                  NaN           NaN           NaN
# chips pretzels                          NaN           NaN           NaN
# cleaning products                       NaN           NaN           NaN
# cocoa drink mixes                       NaN           NaN           NaN
# coffee                                  NaN           NaN           NaN
# cold flu allergy                        NaN           NaN           NaN
# condiments                              NaN           NaN           NaN
# cookies cakes                           NaN           NaN           NaN
# crackers                                NaN           NaN           NaN
# cream                                   NaN           NaN           NaN
# deodorants                              NaN           NaN           NaN
# diapers wipes                           NaN  24723.171123           NaN
# digestion                               NaN           NaN           NaN
# dish detergents                         NaN           NaN           NaN
# dog food care                           NaN           NaN           NaN
# doughs gelatins bake mixes              NaN           NaN           NaN
# dry pasta                               NaN           NaN           NaN
# eggs                                    NaN           NaN           NaN
# energy granola bars                     NaN           NaN           NaN
# energy sports drinks                    NaN           NaN           NaN
# eye ear care                            NaN           NaN           NaN
# facial care                             NaN           NaN           NaN
# feminine care                           NaN           NaN           NaN
# first aid                               NaN           NaN           NaN
# food storage                            NaN           NaN           NaN
# fresh dips tapenades                    NaN           NaN           NaN
# fresh fruits                            NaN           NaN           NaN
# fresh herbs                             NaN           NaN           NaN
# fresh pasta                             NaN           NaN           NaN
# fresh vegetables                        NaN           NaN           NaN
# frozen appetizers sides                 NaN           NaN           NaN
# frozen breads doughs                    NaN           NaN           NaN
# frozen breakfast                        NaN           NaN           NaN
# frozen dessert                          NaN           NaN           NaN
# frozen juice                            NaN           NaN           NaN
# frozen meals                            NaN           NaN           NaN
# frozen meat seafood                     NaN           NaN           NaN
# frozen pizza                            NaN           NaN           NaN
# frozen produce                          NaN           NaN           NaN
# frozen vegan vegetarian                 NaN           NaN           NaN
# fruit vegetable snacks                  NaN           NaN           NaN
# grains rice dried goods                 NaN           NaN           NaN
# granola                                 NaN           NaN           NaN
# hair care                               NaN           NaN           NaN
# honeys syrups nectars                   NaN           NaN           NaN
# hot cereal pancake mixes                NaN           NaN           NaN
# hot dogs bacon sausage                  NaN           NaN           NaN
# ice cream ice                           NaN           NaN           NaN
# ice cream toppings                      NaN           NaN           NaN
# indian foods                            NaN           NaN           NaN
# instant foods                           NaN           NaN           NaN
# juice nectars                           NaN           NaN           NaN
# kitchen supplies                        NaN           NaN           NaN
# kosher foods                            NaN           NaN           NaN
# latino foods                            NaN           NaN           NaN
# laundry                                 NaN           NaN           NaN
# lunch meat                              NaN           NaN           NaN
# marinades meat preparation              NaN           NaN           NaN
# meat counter                            NaN           NaN           NaN
# milk                                    NaN           NaN           NaN
# mint gum                                NaN           NaN           NaN
# missing                                 NaN           NaN           NaN
# more household                          NaN           NaN           NaN
# muscles joints pain relief              NaN           NaN           NaN
# nuts seeds dried fruit                  NaN           NaN           NaN
# oils vinegars                           NaN           NaN           NaN
# oral hygiene                            NaN           NaN           NaN
# other                                   NaN           NaN           NaN
# other creams cheeses                    NaN           NaN           NaN
# packaged cheese                         NaN           NaN           NaN
# packaged meat                           NaN           NaN           NaN
# packaged poultry                        NaN           NaN           NaN
# packaged produce                        NaN           NaN           NaN
# packaged seafood                        NaN           NaN           NaN
# packaged vegetables fruits              NaN           NaN           NaN
# paper goods                             NaN           NaN           NaN
# pasta sauce                             NaN           NaN           NaN
# pickled goods olives                    NaN           NaN           NaN
# plates bowls cups flatware              NaN           NaN           NaN
# popcorn jerky                           NaN           NaN           NaN
# poultry counter                         NaN           NaN           NaN
# prepared meals                          NaN           NaN           NaN
# prepared soups salads                   NaN           NaN           NaN
# preserved dips spreads                  NaN           NaN           NaN
# protein meal replacements               NaN           NaN           NaN
# red wines                      24106.875000           NaN           NaN
# refrigerated                            NaN           NaN           NaN
# refrigerated pudding desserts           NaN           NaN           NaN
# salad dressing toppings                 NaN           NaN           NaN
# seafood counter                         NaN           NaN           NaN
# shave needs                             NaN           NaN           NaN
# skin care                               NaN           NaN           NaN
# soap                                    NaN           NaN           NaN
# soft drinks                             NaN           NaN           NaN
# soup broth bouillon                     NaN           NaN           NaN
# soy lactosefree                         NaN           NaN           NaN
# specialty cheeses                       NaN           NaN           NaN
# specialty wines champagnes     24846.536842           NaN           NaN
# spices seasonings                       NaN           NaN           NaN
# spirits                        25513.302564           NaN           NaN
# spreads                                 NaN           NaN           NaN
# tea                                     NaN           NaN           NaN
# tofu meat alternatives                  NaN           NaN           NaN
# tortillas flat bread                    NaN           NaN  25090.680498
# trail mix snack mix                     NaN           NaN           NaN
# trash bags liners                       NaN           NaN           NaN
# vitamins supplements                    NaN           NaN           NaN
# water seltzer sparkling water           NaN           NaN           NaN
# white wines                    26559.863946           NaN           NaN
# yogurt                                  NaN           NaN           NaN
#
# department                        beverages     breakfast          bulk  \
# aisle
# air fresheners candles                  NaN           NaN           NaN
# asian foods                             NaN           NaN           NaN
# baby accessories                        NaN           NaN           NaN
# baby bath body care                     NaN           NaN           NaN
# baby food formula                       NaN           NaN           NaN
# bakery desserts                         NaN           NaN           NaN
# baking ingredients                      NaN           NaN           NaN
# baking supplies decor                   NaN           NaN           NaN
# beauty                                  NaN           NaN           NaN
# beers coolers                           NaN           NaN           NaN
# body lotions soap                       NaN           NaN           NaN
# bread                                   NaN           NaN           NaN
# breakfast bakery                        NaN           NaN           NaN
# breakfast bars pastries                 NaN  24382.202312           NaN
# bulk dried fruits vegetables            NaN           NaN  20371.750000
# bulk grains rice dried goods            NaN           NaN  27762.730769
# buns rolls                              NaN           NaN           NaN
# butter                                  NaN           NaN           NaN
# candy chocolate                         NaN           NaN           NaN
# canned fruit applesauce                 NaN           NaN           NaN
# canned jarred vegetables                NaN           NaN           NaN
# canned meals beans                      NaN           NaN           NaN
# canned meat seafood                     NaN           NaN           NaN
# cat food care                           NaN           NaN           NaN
# cereal                                  NaN  24845.308370           NaN
# chips pretzels                          NaN           NaN           NaN
# cleaning products                       NaN           NaN           NaN
# cocoa drink mixes              24475.843049           NaN           NaN
# coffee                         24527.476471           NaN           NaN
# cold flu allergy                        NaN           NaN           NaN
# condiments                              NaN           NaN           NaN
# cookies cakes                           NaN           NaN           NaN
# crackers                                NaN           NaN           NaN
# cream                                   NaN           NaN           NaN
# deodorants                              NaN           NaN           NaN
# diapers wipes                           NaN           NaN           NaN
# digestion                               NaN           NaN           NaN
# dish detergents                         NaN           NaN           NaN
# dog food care                           NaN           NaN           NaN
# doughs gelatins bake mixes              NaN           NaN           NaN
# dry pasta                               NaN           NaN           NaN
# eggs                                    NaN           NaN           NaN
# energy granola bars                     NaN           NaN           NaN
# energy sports drinks           24863.027211           NaN           NaN
# eye ear care                            NaN           NaN           NaN
# facial care                             NaN           NaN           NaN
# feminine care                           NaN           NaN           NaN
# first aid                               NaN           NaN           NaN
# food storage                            NaN           NaN           NaN
# fresh dips tapenades                    NaN           NaN           NaN
# fresh fruits                            NaN           NaN           NaN
# fresh herbs                             NaN           NaN           NaN
# fresh pasta                             NaN           NaN           NaN
# fresh vegetables                        NaN           NaN           NaN
# frozen appetizers sides                 NaN           NaN           NaN
# frozen breads doughs                    NaN           NaN           NaN
# frozen breakfast                        NaN           NaN           NaN
# frozen dessert                          NaN           NaN           NaN
# frozen juice                            NaN           NaN           NaN
# frozen meals                            NaN           NaN           NaN
# frozen meat seafood                     NaN           NaN           NaN
# frozen pizza                            NaN           NaN           NaN
# frozen produce                          NaN           NaN           NaN
# frozen vegan vegetarian                 NaN           NaN           NaN
# fruit vegetable snacks                  NaN           NaN           NaN
# grains rice dried goods                 NaN           NaN           NaN
# granola                                 NaN  26274.854054           NaN
# hair care                               NaN           NaN           NaN
# honeys syrups nectars                   NaN           NaN           NaN
# hot cereal pancake mixes                NaN  26482.924092           NaN
# hot dogs bacon sausage                  NaN           NaN           NaN
# ice cream ice                           NaN           NaN           NaN
# ice cream toppings                      NaN           NaN           NaN
# indian foods                            NaN           NaN           NaN
# instant foods                           NaN           NaN           NaN
# juice nectars                  24771.176768           NaN           NaN
# kitchen supplies                        NaN           NaN           NaN
# kosher foods                            NaN           NaN           NaN
# latino foods                            NaN           NaN           NaN
# laundry                                 NaN           NaN           NaN
# lunch meat                              NaN           NaN           NaN
# marinades meat preparation              NaN           NaN           NaN
# meat counter                            NaN           NaN           NaN
# milk                                    NaN           NaN           NaN
# mint gum                                NaN           NaN           NaN
# missing                                 NaN           NaN           NaN
# more household                          NaN           NaN           NaN
# muscles joints pain relief              NaN           NaN           NaN
# nuts seeds dried fruit                  NaN           NaN           NaN
# oils vinegars                           NaN           NaN           NaN
# oral hygiene                            NaN           NaN           NaN
# other                                   NaN           NaN           NaN
# other creams cheeses                    NaN           NaN           NaN
# packaged cheese                         NaN           NaN           NaN
# packaged meat                           NaN           NaN           NaN
# packaged poultry                        NaN           NaN           NaN
# packaged produce                        NaN           NaN           NaN
# packaged seafood                        NaN           NaN           NaN
# packaged vegetables fruits              NaN           NaN           NaN
# paper goods                             NaN           NaN           NaN
# pasta sauce                             NaN           NaN           NaN
# pickled goods olives                    NaN           NaN           NaN
# plates bowls cups flatware              NaN           NaN           NaN
# popcorn jerky                           NaN           NaN           NaN
# poultry counter                         NaN           NaN           NaN
# prepared meals                          NaN           NaN           NaN
# prepared soups salads                   NaN           NaN           NaN
# preserved dips spreads                  NaN           NaN           NaN
# protein meal replacements               NaN           NaN           NaN
# red wines                               NaN           NaN           NaN
# refrigerated                   24171.237037           NaN           NaN
# refrigerated pudding desserts           NaN           NaN           NaN
# salad dressing toppings                 NaN           NaN           NaN
# seafood counter                         NaN           NaN           NaN
# shave needs                             NaN           NaN           NaN
# skin care                               NaN           NaN           NaN
# soap                                    NaN           NaN           NaN
# soft drinks                    23520.237581           NaN           NaN
# soup broth bouillon                     NaN           NaN           NaN
# soy lactosefree                         NaN           NaN           NaN
# specialty cheeses                       NaN           NaN           NaN
# specialty wines champagnes              NaN           NaN           NaN
# spices seasonings                       NaN           NaN           NaN
# spirits                                 NaN           NaN           NaN
# spreads                                 NaN           NaN           NaN
# tea                            24344.529083           NaN           NaN
# tofu meat alternatives                  NaN           NaN           NaN
# tortillas flat bread                    NaN           NaN           NaN
# trail mix snack mix                     NaN           NaN           NaN
# trash bags liners                       NaN           NaN           NaN
# vitamins supplements                    NaN           NaN           NaN
# water seltzer sparkling water  25426.648256           NaN           NaN
# white wines                             NaN           NaN           NaN
# yogurt                                  NaN           NaN           NaN
#
# department                     canned goods    dairy eggs          deli  \
# aisle
# air fresheners candles                  NaN           NaN           NaN
# asian foods                             NaN           NaN           NaN
# baby accessories                        NaN           NaN           NaN
# baby bath body care                     NaN           NaN           NaN
# baby food formula                       NaN           NaN           NaN
# bakery desserts                         NaN           NaN           NaN
# baking ingredients                      NaN           NaN           NaN
# baking supplies decor                   NaN           NaN           NaN
# beauty                                  NaN           NaN           NaN
# beers coolers                           NaN           NaN           NaN
# body lotions soap                       NaN           NaN           NaN
# bread                                   NaN           NaN           NaN
# breakfast bakery                        NaN           NaN           NaN
# breakfast bars pastries                 NaN           NaN           NaN
# bulk dried fruits vegetables            NaN           NaN           NaN
# bulk grains rice dried goods            NaN           NaN           NaN
# buns rolls                              NaN           NaN           NaN
# butter                                  NaN  25196.053333           NaN
# candy chocolate                         NaN           NaN           NaN
# canned fruit applesauce        24943.757202           NaN           NaN
# canned jarred vegetables       24176.455852           NaN           NaN
# canned meals beans             25542.748538           NaN           NaN
# canned meat seafood            26001.462898           NaN           NaN
# cat food care                           NaN           NaN           NaN
# cereal                                  NaN           NaN           NaN
# chips pretzels                          NaN           NaN           NaN
# cleaning products                       NaN           NaN           NaN
# cocoa drink mixes                       NaN           NaN           NaN
# coffee                                  NaN           NaN           NaN
# cold flu allergy                        NaN           NaN           NaN
# condiments                              NaN           NaN           NaN
# cookies cakes                           NaN           NaN           NaN
# crackers                                NaN           NaN           NaN
# cream                                   NaN  23867.633540           NaN
# deodorants                              NaN           NaN           NaN
# diapers wipes                           NaN           NaN           NaN
# digestion                               NaN           NaN           NaN
# dish detergents                         NaN           NaN           NaN
# dog food care                           NaN           NaN           NaN
# doughs gelatins bake mixes              NaN           NaN           NaN
# dry pasta                               NaN           NaN           NaN
# eggs                                    NaN  24980.616000           NaN
# energy granola bars                     NaN           NaN           NaN
# energy sports drinks                    NaN           NaN           NaN
# eye ear care                            NaN           NaN           NaN
# facial care                             NaN           NaN           NaN
# feminine care                           NaN           NaN           NaN
# first aid                               NaN           NaN           NaN
# food storage                            NaN           NaN           NaN
# fresh dips tapenades                    NaN           NaN  24498.345566
# fresh fruits                            NaN           NaN           NaN
# fresh herbs                             NaN           NaN           NaN
# fresh pasta                             NaN           NaN           NaN
# fresh vegetables                        NaN           NaN           NaN
# frozen appetizers sides                 NaN           NaN           NaN
# frozen breads doughs                    NaN           NaN           NaN
# frozen breakfast                        NaN           NaN           NaN
# frozen dessert                          NaN           NaN           NaN
# frozen juice                            NaN           NaN           NaN
# frozen meals                            NaN           NaN           NaN
# frozen meat seafood                     NaN           NaN           NaN
# frozen pizza                            NaN           NaN           NaN
# frozen produce                          NaN           NaN           NaN
# frozen vegan vegetarian                 NaN           NaN           NaN
# fruit vegetable snacks                  NaN           NaN           NaN
# grains rice dried goods                 NaN           NaN           NaN
# granola                                 NaN           NaN           NaN
# hair care                               NaN           NaN           NaN
# honeys syrups nectars                   NaN           NaN           NaN
# hot cereal pancake mixes                NaN           NaN           NaN
# hot dogs bacon sausage                  NaN           NaN           NaN
# ice cream ice                           NaN           NaN           NaN
# ice cream toppings                      NaN           NaN           NaN
# indian foods                            NaN           NaN           NaN
# instant foods                           NaN           NaN           NaN
# juice nectars                           NaN           NaN           NaN
# kitchen supplies                        NaN           NaN           NaN
# kosher foods                            NaN           NaN           NaN
# latino foods                            NaN           NaN           NaN
# laundry                                 NaN           NaN           NaN
# lunch meat                              NaN           NaN  23708.825737
# marinades meat preparation              NaN           NaN           NaN
# meat counter                            NaN           NaN           NaN
# milk                                    NaN  25482.950617           NaN
# mint gum                                NaN           NaN           NaN
# missing                                 NaN           NaN           NaN
# more household                          NaN           NaN           NaN
# muscles joints pain relief              NaN           NaN           NaN
# nuts seeds dried fruit                  NaN           NaN           NaN
# oils vinegars                           NaN           NaN           NaN
# oral hygiene                            NaN           NaN           NaN
# other                                   NaN           NaN           NaN
# other creams cheeses                    NaN  25355.931937           NaN
# packaged cheese                         NaN  25154.989899           NaN
# packaged meat                           NaN           NaN           NaN
# packaged poultry                        NaN           NaN           NaN
# packaged produce                        NaN           NaN           NaN
# packaged seafood                        NaN           NaN           NaN
# packaged vegetables fruits              NaN           NaN           NaN
# paper goods                             NaN           NaN           NaN
# pasta sauce                             NaN           NaN           NaN
# pickled goods olives                    NaN           NaN           NaN
# plates bowls cups flatware              NaN           NaN           NaN
# popcorn jerky                           NaN           NaN           NaN
# poultry counter                         NaN           NaN           NaN
# prepared meals                          NaN           NaN  24332.741325
# prepared soups salads                   NaN           NaN  26955.616438
# preserved dips spreads                  NaN           NaN           NaN
# protein meal replacements               NaN           NaN           NaN
# red wines                               NaN           NaN           NaN
# refrigerated                            NaN           NaN           NaN
# refrigerated pudding desserts           NaN  24519.010204           NaN
# salad dressing toppings                 NaN           NaN           NaN
# seafood counter                         NaN           NaN           NaN
# shave needs                             NaN           NaN           NaN
# skin care                               NaN           NaN           NaN
# soap                                    NaN           NaN           NaN
# soft drinks                             NaN           NaN           NaN
# soup broth bouillon            23418.921303           NaN           NaN
# soy lactosefree                         NaN  25042.668942           NaN
# specialty cheeses                       NaN  22923.059041           NaN
# specialty wines champagnes              NaN           NaN           NaN
# spices seasonings                       NaN           NaN           NaN
# spirits                                 NaN           NaN           NaN
# spreads                                 NaN           NaN           NaN
# tea                                     NaN           NaN           NaN
# tofu meat alternatives                  NaN           NaN  25931.025157
# tortillas flat bread                    NaN           NaN           NaN
# trail mix snack mix                     NaN           NaN           NaN
# trash bags liners                       NaN           NaN           NaN
# vitamins supplements                    NaN           NaN           NaN
# water seltzer sparkling water           NaN           NaN           NaN
# white wines                             NaN           NaN           NaN
# yogurt                                  NaN  24989.298246           NaN
#
# department                     dry goods pasta        frozen     household  \
# aisle
# air fresheners candles                     NaN           NaN  24177.070423
# asian foods                                NaN           NaN           NaN
# baby accessories                           NaN           NaN           NaN
# baby bath body care                        NaN           NaN           NaN
# baby food formula                          NaN           NaN           NaN
# bakery desserts                            NaN           NaN           NaN
# baking ingredients                         NaN           NaN           NaN
# baking supplies decor                      NaN           NaN           NaN
# beauty                                     NaN           NaN           NaN
# beers coolers                              NaN           NaN           NaN
# body lotions soap                          NaN           NaN           NaN
# bread                                      NaN           NaN           NaN
# breakfast bakery                           NaN           NaN           NaN
# breakfast bars pastries                    NaN           NaN           NaN
# bulk dried fruits vegetables               NaN           NaN           NaN
# bulk grains rice dried goods               NaN           NaN           NaN
# buns rolls                                 NaN           NaN           NaN
# butter                                     NaN           NaN           NaN
# candy chocolate                            NaN           NaN           NaN
# canned fruit applesauce                    NaN           NaN           NaN
# canned jarred vegetables                   NaN           NaN           NaN
# canned meals beans                         NaN           NaN           NaN
# canned meat seafood                        NaN           NaN           NaN
# cat food care                              NaN           NaN           NaN
# cereal                                     NaN           NaN           NaN
# chips pretzels                             NaN           NaN           NaN
# cleaning products                          NaN           NaN  24374.572519
# cocoa drink mixes                          NaN           NaN           NaN
# coffee                                     NaN           NaN           NaN
# cold flu allergy                           NaN           NaN           NaN
# condiments                                 NaN           NaN           NaN
# cookies cakes                              NaN           NaN           NaN
# crackers                                   NaN           NaN           NaN
# cream                                      NaN           NaN           NaN
# deodorants                                 NaN           NaN           NaN
# diapers wipes                              NaN           NaN           NaN
# digestion                                  NaN           NaN           NaN
# dish detergents                            NaN           NaN  24824.632353
# dog food care                              NaN           NaN           NaN
# doughs gelatins bake mixes                 NaN           NaN           NaN
# dry pasta                         24263.566740           NaN           NaN
# eggs                                       NaN           NaN           NaN
# energy granola bars                        NaN           NaN           NaN
# energy sports drinks                       NaN           NaN           NaN
# eye ear care                               NaN           NaN           NaN
# facial care                                NaN           NaN           NaN
# feminine care                              NaN           NaN           NaN
# first aid                                  NaN           NaN           NaN
# food storage                               NaN           NaN  24692.218447
# fresh dips tapenades                       NaN           NaN           NaN
# fresh fruits                               NaN           NaN           NaN
# fresh herbs                                NaN           NaN           NaN
# fresh pasta                       25674.455285           NaN           NaN
# fresh vegetables                           NaN           NaN           NaN
# frozen appetizers sides                    NaN  25649.341969           NaN
# frozen breads doughs                       NaN  25361.629630           NaN
# frozen breakfast                           NaN  23729.243243           NaN
# frozen dessert                             NaN  25069.017857           NaN
# frozen juice                               NaN  23303.680851           NaN
# frozen meals                               NaN  24839.272727           NaN
# frozen meat seafood                        NaN  23989.851528           NaN
# frozen pizza                               NaN  25427.170149           NaN
# frozen produce                             NaN  23874.584488           NaN
# frozen vegan vegetarian                    NaN  22579.841270           NaN
# fruit vegetable snacks                     NaN           NaN           NaN
# grains rice dried goods           26659.544643           NaN           NaN
# granola                                    NaN           NaN           NaN
# hair care                                  NaN           NaN           NaN
# honeys syrups nectars                      NaN           NaN           NaN
# hot cereal pancake mixes                   NaN           NaN           NaN
# hot dogs bacon sausage                     NaN           NaN           NaN
# ice cream ice                              NaN  25131.948671           NaN
# ice cream toppings                         NaN           NaN           NaN
# indian foods                               NaN           NaN           NaN
# instant foods                     25426.607735           NaN           NaN
# juice nectars                              NaN           NaN           NaN
# kitchen supplies                           NaN           NaN  23700.944954
# kosher foods                               NaN           NaN           NaN
# latino foods                               NaN           NaN           NaN
# laundry                                    NaN           NaN  23860.715415
# lunch meat                                 NaN           NaN           NaN
# marinades meat preparation                 NaN           NaN           NaN
# meat counter                               NaN           NaN           NaN
# milk                                       NaN           NaN           NaN
# mint gum                                   NaN           NaN           NaN
# missing                                    NaN           NaN           NaN
# more household                             NaN           NaN  24470.785714
# muscles joints pain relief                 NaN           NaN           NaN
# nuts seeds dried fruit                     NaN           NaN           NaN
# oils vinegars                              NaN           NaN           NaN
# oral hygiene                               NaN           NaN           NaN
# other                                      NaN           NaN           NaN
# other creams cheeses                       NaN           NaN           NaN
# packaged cheese                            NaN           NaN           NaN
# packaged meat                              NaN           NaN           NaN
# packaged poultry                           NaN           NaN           NaN
# packaged produce                           NaN           NaN           NaN
# packaged seafood                           NaN           NaN           NaN
# packaged vegetables fruits                 NaN           NaN           NaN
# paper goods                                NaN           NaN  24482.661491
# pasta sauce                       24255.461153           NaN           NaN
# pickled goods olives                       NaN           NaN           NaN
# plates bowls cups flatware                 NaN           NaN  23810.000000
# popcorn jerky                              NaN           NaN           NaN
# poultry counter                            NaN           NaN           NaN
# prepared meals                             NaN           NaN           NaN
# prepared soups salads                      NaN           NaN           NaN
# preserved dips spreads                     NaN           NaN           NaN
# protein meal replacements                  NaN           NaN           NaN
# red wines                                  NaN           NaN           NaN
# refrigerated                               NaN           NaN           NaN
# refrigerated pudding desserts              NaN           NaN           NaN
# salad dressing toppings                    NaN           NaN           NaN
# seafood counter                            NaN           NaN           NaN
# shave needs                                NaN           NaN           NaN
# skin care                                  NaN           NaN           NaN
# soap                                       NaN           NaN           NaN
# soft drinks                                NaN           NaN           NaN
# soup broth bouillon                        NaN           NaN           NaN
# soy lactosefree                            NaN           NaN           NaN
# specialty cheeses                          NaN           NaN           NaN
# specialty wines champagnes                 NaN           NaN           NaN
# spices seasonings                          NaN           NaN           NaN
# spirits                                    NaN           NaN           NaN
# spreads                                    NaN           NaN           NaN
# tea                                        NaN           NaN           NaN
# tofu meat alternatives                     NaN           NaN           NaN
# tortillas flat bread                       NaN           NaN           NaN
# trail mix snack mix                        NaN           NaN           NaN
# trash bags liners                          NaN           NaN  24487.401786
# vitamins supplements                       NaN           NaN           NaN
# water seltzer sparkling water              NaN           NaN           NaN
# white wines                                NaN           NaN           NaN
# yogurt                                     NaN           NaN           NaN
#
# department                     international  meat seafood       missing  \
# aisle
# air fresheners candles                   NaN           NaN           NaN
# asian foods                     24360.928926           NaN           NaN
# baby accessories                         NaN           NaN           NaN
# baby bath body care                      NaN           NaN           NaN
# baby food formula                        NaN           NaN           NaN
# bakery desserts                          NaN           NaN           NaN
# baking ingredients                       NaN           NaN           NaN
# baking supplies decor                    NaN           NaN           NaN
# beauty                                   NaN           NaN           NaN
# beers coolers                            NaN           NaN           NaN
# body lotions soap                        NaN           NaN           NaN
# bread                                    NaN           NaN           NaN
# breakfast bakery                         NaN           NaN           NaN
# breakfast bars pastries                  NaN           NaN           NaN
# bulk dried fruits vegetables             NaN           NaN           NaN
# bulk grains rice dried goods             NaN           NaN           NaN
# buns rolls                               NaN           NaN           NaN
# butter                                   NaN           NaN           NaN
# candy chocolate                          NaN           NaN           NaN
# canned fruit applesauce                  NaN           NaN           NaN
# canned jarred vegetables                 NaN           NaN           NaN
# canned meals beans                       NaN           NaN           NaN
# canned meat seafood                      NaN           NaN           NaN
# cat food care                            NaN           NaN           NaN
# cereal                                   NaN           NaN           NaN
# chips pretzels                           NaN           NaN           NaN
# cleaning products                        NaN           NaN           NaN
# cocoa drink mixes                        NaN           NaN           NaN
# coffee                                   NaN           NaN           NaN
# cold flu allergy                         NaN           NaN           NaN
# condiments                               NaN           NaN           NaN
# cookies cakes                            NaN           NaN           NaN
# crackers                                 NaN           NaN           NaN
# cream                                    NaN           NaN           NaN
# deodorants                               NaN           NaN           NaN
# diapers wipes                            NaN           NaN           NaN
# digestion                                NaN           NaN           NaN
# dish detergents                          NaN           NaN           NaN
# dog food care                            NaN           NaN           NaN
# doughs gelatins bake mixes               NaN           NaN           NaN
# dry pasta                                NaN           NaN           NaN
# eggs                                     NaN           NaN           NaN
# energy granola bars                      NaN           NaN           NaN
# energy sports drinks                     NaN           NaN           NaN
# eye ear care                             NaN           NaN           NaN
# facial care                              NaN           NaN           NaN
# feminine care                            NaN           NaN           NaN
# first aid                                NaN           NaN           NaN
# food storage                             NaN           NaN           NaN
# fresh dips tapenades                     NaN           NaN           NaN
# fresh fruits                             NaN           NaN           NaN
# fresh herbs                              NaN           NaN           NaN
# fresh pasta                              NaN           NaN           NaN
# fresh vegetables                         NaN           NaN           NaN
# frozen appetizers sides                  NaN           NaN           NaN
# frozen breads doughs                     NaN           NaN           NaN
# frozen breakfast                         NaN           NaN           NaN
# frozen dessert                           NaN           NaN           NaN
# frozen juice                             NaN           NaN           NaN
# frozen meals                             NaN           NaN           NaN
# frozen meat seafood                      NaN           NaN           NaN
# frozen pizza                             NaN           NaN           NaN
# frozen produce                           NaN           NaN           NaN
# frozen vegan vegetarian                  NaN           NaN           NaN
# fruit vegetable snacks                   NaN           NaN           NaN
# grains rice dried goods                  NaN           NaN           NaN
# granola                                  NaN           NaN           NaN
# hair care                                NaN           NaN           NaN
# honeys syrups nectars                    NaN           NaN           NaN
# hot cereal pancake mixes                 NaN           NaN           NaN
# hot dogs bacon sausage                   NaN  25533.379845           NaN
# ice cream ice                            NaN           NaN           NaN
# ice cream toppings                       NaN           NaN           NaN
# indian foods                    24873.370370           NaN           NaN
# instant foods                            NaN           NaN           NaN
# juice nectars                            NaN           NaN           NaN
# kitchen supplies                         NaN           NaN           NaN
# kosher foods                    24527.130178           NaN           NaN
# latino foods                    25356.817121           NaN           NaN
# laundry                                  NaN           NaN           NaN
# lunch meat                               NaN           NaN           NaN
# marinades meat preparation               NaN           NaN           NaN
# meat counter                             NaN  27560.314286           NaN
# milk                                     NaN           NaN           NaN
# mint gum                                 NaN           NaN           NaN
# missing                                  NaN           NaN  25203.929253
# more household                           NaN           NaN           NaN
# ...
# frozen breakfast                        NaN           NaN            NaN
# frozen dessert                          NaN           NaN            NaN
# frozen juice                            NaN           NaN            NaN
# frozen meals                            NaN           NaN            NaN
# frozen meat seafood                     NaN           NaN            NaN
# frozen pizza                            NaN           NaN            NaN
# frozen produce                          NaN           NaN            NaN
# frozen vegan vegetarian                 NaN           NaN            NaN
# fruit vegetable snacks                  NaN           NaN            NaN
# grains rice dried goods                 NaN           NaN            NaN
# granola                                 NaN           NaN            NaN
# hair care                               NaN           NaN   24381.524510
# honeys syrups nectars                   NaN  26471.484716            NaN
# hot cereal pancake mixes                NaN           NaN            NaN
# hot dogs bacon sausage                  NaN           NaN            NaN
# ice cream ice                           NaN           NaN            NaN
# ice cream toppings                      NaN           NaN            NaN
# indian foods                            NaN           NaN            NaN
# instant foods                           NaN           NaN            NaN
# juice nectars                           NaN           NaN            NaN
# kitchen supplies                        NaN           NaN            NaN
# kosher foods                            NaN           NaN            NaN
# latino foods                            NaN           NaN            NaN
# laundry                                 NaN           NaN            NaN
# lunch meat                              NaN           NaN            NaN
# marinades meat preparation              NaN  25240.210269            NaN
# meat counter                            NaN           NaN            NaN
# milk                                    NaN           NaN            NaN
# mint gum                                NaN           NaN            NaN
# missing                                 NaN           NaN            NaN
# more household                          NaN           NaN            NaN
# muscles joints pain relief              NaN           NaN   23249.720930
# nuts seeds dried fruit                  NaN           NaN            NaN
# oils vinegars                           NaN  24971.210667            NaN
# oral hygiene                            NaN           NaN   24223.035398
# other                          25679.793796           NaN            NaN
# other creams cheeses                    NaN           NaN            NaN
# packaged cheese                         NaN           NaN            NaN
# packaged meat                           NaN           NaN            NaN
# packaged poultry                        NaN           NaN            NaN
# packaged produce                        NaN           NaN            NaN
# packaged seafood                        NaN           NaN            NaN
# packaged vegetables fruits              NaN           NaN            NaN
# paper goods                             NaN           NaN            NaN
# pasta sauce                             NaN           NaN            NaN
# pickled goods olives                    NaN  24516.373134            NaN
# plates bowls cups flatware              NaN           NaN            NaN
# popcorn jerky                           NaN           NaN            NaN
# poultry counter                         NaN           NaN            NaN
# prepared meals                          NaN           NaN            NaN
# prepared soups salads                   NaN           NaN            NaN
# preserved dips spreads                  NaN  26076.166667            NaN
# protein meal replacements               NaN           NaN   25647.495385
# red wines                               NaN           NaN            NaN
# refrigerated                            NaN           NaN            NaN
# refrigerated pudding desserts           NaN           NaN            NaN
# salad dressing toppings                 NaN  25641.980357            NaN
# seafood counter                         NaN           NaN            NaN
# shave needs                             NaN           NaN   24306.166667
# skin care                               NaN           NaN   24572.844898
# soap                                    NaN           NaN   25143.066667
# soft drinks                             NaN           NaN            NaN
# soup broth bouillon                     NaN           NaN            NaN
# soy lactosefree                         NaN           NaN            NaN
# specialty cheeses                       NaN           NaN            NaN
# specialty wines champagnes              NaN           NaN            NaN
# spices seasonings                       NaN  25430.494354            NaN
# spirits                                 NaN           NaN            NaN
# spreads                                 NaN  24056.097363            NaN
# tea                                     NaN           NaN            NaN
# tofu meat alternatives                  NaN           NaN            NaN
# tortillas flat bread                    NaN           NaN            NaN
# trail mix snack mix                     NaN           NaN            NaN
# trash bags liners                       NaN           NaN            NaN
# vitamins supplements                    NaN           NaN   24422.051060
# water seltzer sparkling water           NaN           NaN            NaN
# white wines                             NaN           NaN            NaN
# yogurt                                  NaN           NaN            NaN
#
# department                             pets       produce        snacks
# aisle
# air fresheners candles                  NaN           NaN           NaN
# asian foods                             NaN           NaN           NaN
# baby accessories                        NaN           NaN           NaN
# baby bath body care                     NaN           NaN           NaN
# baby food formula                       NaN           NaN           NaN
# bakery desserts                         NaN           NaN           NaN
# baking ingredients                      NaN           NaN           NaN
# baking supplies decor                   NaN           NaN           NaN
# beauty                                  NaN           NaN           NaN
# beers coolers                           NaN           NaN           NaN
# body lotions soap                       NaN           NaN           NaN
# bread                                   NaN           NaN           NaN
# breakfast bakery                        NaN           NaN           NaN
# breakfast bars pastries                 NaN           NaN           NaN
# bulk dried fruits vegetables            NaN           NaN           NaN
# bulk grains rice dried goods            NaN           NaN           NaN
# buns rolls                              NaN           NaN           NaN
# butter                                  NaN           NaN           NaN
# candy chocolate                         NaN           NaN  25709.383628
# canned fruit applesauce                 NaN           NaN           NaN
# canned jarred vegetables                NaN           NaN           NaN
# canned meals beans                      NaN           NaN           NaN
# canned meat seafood                     NaN           NaN           NaN
# cat food care                  24998.969940           NaN           NaN
# cereal                                  NaN           NaN           NaN
# chips pretzels                          NaN           NaN  25595.253792
# cleaning products                       NaN           NaN           NaN
# cocoa drink mixes                       NaN           NaN           NaN
# coffee                                  NaN           NaN           NaN
# cold flu allergy                        NaN           NaN           NaN
# condiments                              NaN           NaN           NaN
# cookies cakes                           NaN           NaN  24550.459954
# crackers                                NaN           NaN  24703.570281
# cream                                   NaN           NaN           NaN
# deodorants                              NaN           NaN           NaN
# diapers wipes                           NaN           NaN           NaN
# digestion                               NaN           NaN           NaN
# dish detergents                         NaN           NaN           NaN
# dog food care                  24516.566596           NaN           NaN
# doughs gelatins bake mixes              NaN           NaN           NaN
# dry pasta                               NaN           NaN           NaN
# eggs                                    NaN           NaN           NaN
# energy granola bars                     NaN           NaN  24455.054087
# energy sports drinks                    NaN           NaN           NaN
# eye ear care                            NaN           NaN           NaN
# facial care                             NaN           NaN           NaN
# feminine care                           NaN           NaN           NaN
# first aid                               NaN           NaN           NaN
# food storage                            NaN           NaN           NaN
# fresh dips tapenades                    NaN           NaN           NaN
# fresh fruits                            NaN  25343.615183           NaN
# fresh herbs                             NaN  22363.069767           NaN
# fresh pasta                             NaN           NaN           NaN
# fresh vegetables                        NaN  24440.302285           NaN
# frozen appetizers sides                 NaN           NaN           NaN
# frozen breads doughs                    NaN           NaN           NaN
# frozen breakfast                        NaN           NaN           NaN
# frozen dessert                          NaN           NaN           NaN
# frozen juice                            NaN           NaN           NaN
# frozen meals                            NaN           NaN           NaN
# frozen meat seafood                     NaN           NaN           NaN
# frozen pizza                            NaN           NaN           NaN
# frozen produce                          NaN           NaN           NaN
# frozen vegan vegetarian                 NaN           NaN           NaN
# fruit vegetable snacks                  NaN           NaN  25258.859551
# grains rice dried goods                 NaN           NaN           NaN
# granola                                 NaN           NaN           NaN
# hair care                               NaN           NaN           NaN
# honeys syrups nectars                   NaN           NaN           NaN
# hot cereal pancake mixes                NaN           NaN           NaN
# hot dogs bacon sausage                  NaN           NaN           NaN
# ice cream ice                           NaN           NaN           NaN
# ice cream toppings                      NaN           NaN  23762.000000
# indian foods                            NaN           NaN           NaN
# instant foods                           NaN           NaN           NaN
# juice nectars                           NaN           NaN           NaN
# kitchen supplies                        NaN           NaN           NaN
# kosher foods                            NaN           NaN           NaN
# latino foods                            NaN           NaN           NaN
# laundry                                 NaN           NaN           NaN
# lunch meat                              NaN           NaN           NaN
# marinades meat preparation              NaN           NaN           NaN
# meat counter                            NaN           NaN           NaN
# milk                                    NaN           NaN           NaN
# mint gum                                NaN           NaN  25769.166667
# missing                                 NaN           NaN           NaN
# more household                          NaN           NaN           NaN
# muscles joints pain relief              NaN           NaN           NaN
# nuts seeds dried fruit                  NaN           NaN  24448.625430
# oils vinegars                           NaN           NaN           NaN
# oral hygiene                            NaN           NaN           NaN
# other                                   NaN           NaN           NaN
# other creams cheeses                    NaN           NaN           NaN
# packaged cheese                         NaN           NaN           NaN
# packaged meat                           NaN           NaN           NaN
# packaged poultry                        NaN           NaN           NaN
# packaged produce                        NaN  20831.343750           NaN
# packaged seafood                        NaN           NaN           NaN
# packaged vegetables fruits              NaN  24138.569106           NaN
# paper goods                             NaN           NaN           NaN
# pasta sauce                             NaN           NaN           NaN
# pickled goods olives                    NaN           NaN           NaN
# plates bowls cups flatware              NaN           NaN           NaN
# popcorn jerky                           NaN           NaN  24321.569620
# poultry counter                         NaN           NaN           NaN
# prepared meals                          NaN           NaN           NaN
# prepared soups salads                   NaN           NaN           NaN
# preserved dips spreads                  NaN           NaN           NaN
# protein meal replacements               NaN           NaN           NaN
# red wines                               NaN           NaN           NaN
# refrigerated                            NaN           NaN           NaN
# refrigerated pudding desserts           NaN           NaN           NaN
# salad dressing toppings                 NaN           NaN           NaN
# seafood counter                         NaN           NaN           NaN
# shave needs                             NaN           NaN           NaN
# skin care                               NaN           NaN           NaN
# soap                                    NaN           NaN           NaN
# soft drinks                             NaN           NaN           NaN
# soup broth bouillon                     NaN           NaN           NaN
# soy lactosefree                         NaN           NaN           NaN
# specialty cheeses                       NaN           NaN           NaN
# specialty wines champagnes              NaN           NaN           NaN
# spices seasonings                       NaN           NaN           NaN
# spirits                                 NaN           NaN           NaN
# spreads                                 NaN           NaN           NaN
# tea                                     NaN           NaN           NaN
# tofu meat alternatives                  NaN           NaN           NaN
# tortillas flat bread                    NaN           NaN           NaN
# trail mix snack mix                     NaN           NaN  24474.231884
# trash bags liners                       NaN           NaN           NaN
# vitamins supplements                    NaN           NaN           NaN
# water seltzer sparkling water           NaN           NaN           NaN
# white wines                             NaN           NaN           NaN
# yogurt                                  NaN           NaN           NaN

# %% [markdown]
# ## Summary of Exploration
# Looking at the unique value counts across our datasets we learn that our source data:
# - Contains information about over 3MM (3,421,083) orders placed by around 200K (206,209) unique customers.
# - Describes nearly 50K (49,688) unique products, from 21 different departments, stored across 134 aisles.
# - Provides details about items that were ordered multiple times (order_products__*.reordered), and orders placed 24/7.
# - Is limited to the first 100 orders placed by a given user.
# - Has missing values for "days_since_prior_order" in the file containing orders. This seems expected since each customer's first order should have no value for this attribute.
#
#
#
# There are two files containing information about product orders that can be combined into a single file: order_products__train and order_products__prior.

# %%
# Save to new 'raw file' prior to S3 upload with desired folder structure

from datetime import datetime
current_dateTime = datetime.now()

#def save_df 

#def save_spark_df

#zone = raw|processed|curated

# path --> f'{key}/{zone}/{year}/{month}/{day}/{file_name}'

# %%
aisles.to_csv(f'/Users/margiehenry/Projects/cloud_dw_from_csv/raw/aisles/\
    {current_dateTime.year}/{current_dateTime.month}/{current_dateTime.day}/aisles.csv')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 aisles.to_csv(f'/Users/margiehenry/Projects/cloud_dw_from_csv/raw/aisles/{current_dateTime.year}/{current_dateTime.month}/{current_dateTime.day}/aisles.csv')
#
# File ~/Projects/cloud_dw_from_csv/venv/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/Projects/cloud_dw_from_csv/venv/lib/python3.10/site-packages/pandas/core/generic.py:3720, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3709 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3711 formatter = DataFrameFormatter(
#    3712     frame=df,
#    3713     header=header,
#    (...)
#    3717     decimal=decimal,
#    3718 )
# -> 3720 return DataFrameRenderer(formatter).to_csv(
#    3721     path_or_buf,
#    3722     lineterminator=lineterminator,
#    3723     sep=sep,
#    3724     encoding=encoding,
#    3725     errors=errors,
#    3726     compression=compression,
#    3727     quoting=quoting,
#    3728     columns=columns,
#    3729     index_label=index_label,
#    3730     mode=mode,
#    3731     chunksize=chunksize,
#    3732     quotechar=quotechar,
#    3733     date_format=date_format,
#    3734     doublequote=doublequote,
#    3735     escapechar=escapechar,
#    3736     storage_options=storage_options,
#    3737 )
#
# File ~/Projects/cloud_dw_from_csv/venv/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/Projects/cloud_dw_from_csv/venv/lib/python3.10/site-packages/pandas/io/formats/format.py:1189, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1168     created_buffer = False
#    1170 csv_formatter = CSVFormatter(
#    1171     path_or_buf=path_or_buf,
#    1172     lineterminator=lineterminator,
#    (...)
#    1187     formatter=self.fmt,
#    1188 )
# -> 1189 csv_formatter.save()
#    1191 if created_buffer:
#    1192     assert isinstance(path_or_buf, StringIO)
#
# File ~/Projects/cloud_dw_from_csv/venv/lib/python3.10/site-packages/pandas/io/formats/csvs.py:241, in CSVFormatter.save(self)
#     237 """
#     238 Create the writer & save.
#     239 """
#     240 # apply compression and byte/text conversion
# --> 241 with get_handle(
#     242     self.filepath_or_buffer,
#     243     self.mode,
#     244     encoding=self.encoding,
#     245     errors=self.errors,
#     246     compression=self.compression,
#     247     storage_options=self.storage_options,
#     248 ) as handles:
#     249
#     250     # Note: self.encoding is irrelevant here
#     251     self.writer = csvlib.writer(
#     252         handles.handle,
#     253         lineterminator=self.lineterminator,
#    (...)
#     258         quotechar=self.quotechar,
#     259     )
#     261     self._save()
#
# File ~/Projects/cloud_dw_from_csv/venv/lib/python3.10/site-packages/pandas/io/common.py:734, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     732 # Only for write methods
#     733 if "r" not in mode and is_path:
# --> 734     check_parent_directory(str(handle))
#     736 if compression:
#     737     if compression != "zstd":
#     738         # compression libraries do not like an explicit text-mode
#
# File ~/Projects/cloud_dw_from_csv/venv/lib/python3.10/site-packages/pandas/io/common.py:597, in check_parent_directory(path)
#     595 parent = Path(path).parent
#     596 if not parent.is_dir():
# --> 597     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: '/Users/margiehenry/Projects/cloud_dw_from_csv/raw/aisles/2023/1/9'

# %%
current_dateTime.day
# Out:
# 9

# %% [markdown]
# ## Data Modelings
#
# An entity relationship model representing (ERG) our transactional data is as follows:
#
# ![Transactional data ERG](images/transactional_tables.png)

# %% [markdown]
# ## Star Schema
# Next, we'll design a star schema optimized for order analysis using our csv files representing transactional data.
#
# The business process we want to model is product orders, so the count of orders will be the transactional fact at the center of our star schema. A single entry in the fact table will represent the number of orders placed, for a given product, by a specific customer during a certain shopping period.
#
# - We will create a "dim_periods" table by serializing unique combinations of "day of the week" and "time of day." Information about transaction dates and holidays are good data points for future iterations of this table.
# - The orders dimensions table will describe who placed an order, the period of time since a customer's last order, and customer order sequencing information.
# - The products dimensions table will house product names. Adding product costs (when available) would allow our facts table to include information about total revenue generated.
# - The departments and aisles tables can remian as they are.
#
# The resulting star schema is:
#
# ![Transactional data ERG](images/star_schema_main.png)

# %% [markdown]
# # Working with AWS

# %% [markdown]
# ### Imports

# %%
from datetime import datetime

import boto3
import json
import configparser
import logging
from botocore.exceptions import ClientError

# %% [markdown]
# ## Configure Secrets

# %% [markdown]
# To begin, we'll need to setup a file called "dwh.cfg", which will hold all of the secret configurations details that will be need to create our Redshift cluster. Our **dwh.cfg should not be added to github**. We can avoid revealing our secrets by added this file to our .gitignore. The dwh.cfg file should contain the following sections, identified using brackets, along with the key-value pairs representing our secrets:
#
# ```
# [AWS]
# AWS_KEY_ID=<your AWS role id>
# AWS_SECRET_KEY=<your AWS role secret key>
# DEFAULT_REGION=<your default region>
# ACCOUNT=<your AWS account number>
#
# ```
#
# Docs for configparser, which demonstrate a basic config file can be fund here: https://docs.python.org/3/library/configparser.html#quick-start
#
# After importing the parser, and creating an instance of it, we will read our 'dwh.cfg' file and use the parser's `get()` method to access our secrets.
#
# We'll use a config file with configparser instead of the AWS Secrets Manager.

# %%
config = configparser.ConfigParser()
config.read_file(open('dwh.cfg'))

KEY = config.get('AWS', 'AWS_KEY_ID')
SECRET = config.get('AWS', 'AWS_SECRET_KEY')
DEFAULT_REGION = config.get('AWS', 'DEFAULT_REGION')
ACCOUNT = config.get('AWS', 'ACCOUNT')
IAM_ROLE_NAME = config.get("DWH", "IAM_ROLE_NAME")
GLUE_ROLE_NAME = config.get("DWH", "glue-role-name")
GLUE_DB_NAME = config.get("DWH", "glue-db-name")

# %% [markdown]
# ## Use the Python SDK Boto3 to Create an S3 bucket.
#
# With AWS access secrets configured, we can use Boto3 to create an S3 bucket.

# %%
iam = boto3.client('iam', region_name=DEFAULT_REGION, 
                  aws_access_key_id=KEY, 
                  aws_secret_access_key=SECRET)

# %%
s3 = boto3.resource('s3', region_name=DEFAULT_REGION, 
                  aws_access_key_id=KEY, 
                  aws_secret_access_key=SECRET)

def create_bucket(bucket_name, s3_resource, region):
    try:
        if region is None:
            s3_resource.create_bucket(Bucket=bucket_name)
        else:
            s3_resource = boto3.resource('s3', region_name=region)
            location = {'LocationConstraint': region}
            s3_resource.create_bucket(Bucket=bucket_name,
                                    CreateBucketConfiguration=location)
    except ClientError as e:
        logging.error(e)
        return False
    return True

bucket_name = 'productdatauseast1'
create_bucket(bucket_name, s3, None)
# Out:
# True

# %% [markdown]
# Note: Because my default region is us-east-1, I do not need to pass this constraint when creating a bucket. Doing so will result in the error `An error occurred (InvalidLocationConstraint) when calling the CreateBucket operation: The specified location-constraint is not valid`
#
# Docs: https://boto3.amazonaws.com/v1/documentation/api/latest/guide/s3-example-creating-buckets.html#create-an-amazon-s3-bucket

# %% [markdown]
# ## Create a Resource-Based Bucket Policy
#
# We'll create a policy which ensures that our bucket is private, and only the account root user can performs S3 actions. This setup accomodates our current pipeline, but would need to be altered if we used other AWS resources upstream.
#
#
# Docs: https://boto3.amazonaws.com/v1/documentation/api/latest/guide/s3-example-bucket-policies.html#set-a-bucket-policy

# %%
bucket_policy = {
    'Version': '2012-10-17',
    'Statement': [{
        'Sid': 'AddPerm',
        'Effect': 'Allow',
        'Principal': {
            "AWS": f"arn:aws:iam::{ACCOUNT}:root"
        },
        'Action': "s3:*",
        'Resource': [f"arn:aws:s3:::{bucket_name}",f"arn:aws:s3:::{bucket_name}/*"]
    }]
}

# Convert the policy from JSON dict to string
bucket_policy = json.dumps(bucket_policy)

# Set the new policy
s3 = boto3.client('s3')
s3.put_bucket_policy(Bucket=bucket_name, Policy=bucket_policy)
# Out:
# {'ResponseMetadata': {'RequestId': 'NKN66E39HHSYJ6QN',
#   'HostId': '3JgSC7Lv3aoMPJmLlGqL4fKwOC7TemkkK9jOhSGIl0KGQpdjMzCURCIewUD6j/RStIAW/k9AFQ4=',
#   'HTTPStatusCode': 204,
#   'HTTPHeaders': {'x-amz-id-2': '3JgSC7Lv3aoMPJmLlGqL4fKwOC7TemkkK9jOhSGIl0KGQpdjMzCURCIewUD6j/RStIAW/k9AFQ4=',
#    'x-amz-request-id': 'NKN66E39HHSYJ6QN',
#    'date': 'Mon, 09 Jan 2023 20:36:25 GMT',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ## Upload sample data from `source_data` directory.
#
# While this step can be accomplished using a number of methods, my prefered being through the use of the boto3, we'll opt for an approach where we walk a given directory, and upload files to S3 with their given names.

# %%
def upload_file(file_path_list, bucket_name, s3_client):
    for file_path in file_path_list:
        try:
            filename = Path(file_path).stem
#             response = s3_client.upload_file(file_path, bucket_name, f'souredata/raw/{}/{filename}')
            logging.info(f"{filename} successfully upload to {bucket_name}")
        except ClientError as e:
            logging.error(e)
            return False
    return True
    
upload_file(file_path_list, bucket_name, s3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 12
#       9             return False
#      10     return True
# ---> 12 upload_file(file_path_list, bucket_name, s3)
#
# NameError: name 'file_path_list' is not defined

# %% [markdown]
# ## View the content of the S3 bucket
#
# Note: If we were working with a large quantity of file we could pass in the `MaxKeys` parameter to limit the number of objects returned from out call to `s3.list_objects()`.

# %%
s3_client = boto3.client("s3")
kwargs = {'Bucket': bucket_name}

response = s3_client.list_objects_v2(**kwargs)

for file in response.get("Contents"):
    print(file["Key"])
# Out:
# souredata/aisles
# souredata/departments
# souredata/order_products__prior
# souredata/order_products__train
# souredata/orders
# souredata/products

# %% [markdown]
# ## Create an EC2 instance

# %% [markdown]
# ### Use the aws-cli to describe-vpcs api to get the VpcID that should be granted access to S3

# %%
# !aws ec2 describe-vpcs
# Out:
# {
#     "Vpcs": [
#         {
#             "CidrBlock": "172.31.0.0/16",
#             "DhcpOptionsId": "dopt-02cbe92f0bd93e7f8",
#             "State": "available",
#             "VpcId": "vpc-0439e54e72f5467b2",
#             "OwnerId": "252119340719",
#             "InstanceTenancy": "default",
#             "CidrBlockAssociationSet": [
#                 {
#                     "AssociationId": "vpc-cidr-assoc-0dd3ee306a88dc8cd",
#                     "CidrBlock": "172.31.0.0/16",
#                     "CidrBlockState": {
#                         "State": "associated"
#                     }
#                 }
#             ],
#             "IsDefault": true
#         }
#     ]
# }

# %% [markdown]
# ### Get the RouteTableId that will be used to configure the gateway.

# %%
# !aws ec2 describe-route-tables
# Out:
# {
#     "RouteTables": [
#         {
#             "Associations": [
#                 {
#                     "Main": true,
#                     "RouteTableAssociationId": "rtbassoc-019f72fce23979684",
#                     "RouteTableId": "rtb-01041395851240626",
#                     "AssociationState": {
#                         "State": "associated"
#                     }
#                 }
#             ],
#             "PropagatingVgws": [],
#             "RouteTableId": "rtb-01041395851240626",
#             "Routes": [
#                 {
#                     "DestinationCidrBlock": "172.31.0.0/16",
#                     "GatewayId": "local",
#                     "Origin": "CreateRouteTable",
#                     "State": "active"
#                 },
#                 {
#                     "DestinationCidrBlock": "0.0.0.0/0",
#                     "GatewayId": "igw-07802e8797cd06177",
#                     "Origin": "CreateRoute",
#                     "State": "active"
#                 }
#             ],
#             "Tags": [],
#             "VpcId": "vpc-0439e54e72f5467b2",
#             "OwnerId": "252119340719"
#         }
#     ]
# }

# %% [markdown]
# ### Create the VPC gateway entrypoint
#
# Use the EC2 VPC andRouting Tables to create an S3 Gateway Endpoint.

# %%
# !aws ec2 create-vpc-endpoint --vpc-id vpc-0439e54e72f5467b2 \
    --service-name com.amazonaws.us-east-1.s3 --route-table-ids rtb-01041395851240626
# Out:
# An error occurred (RouteAlreadyExists) when calling the CreateVpcEndpoint operation: route table rtb-01041395851240626 already has a route with destination-prefix-list-id pl-63a5400a

# %% [markdown]
# ## AWS Glue
#
# We'll use AWS Glue to:
# Read data from S3
# Run a severless ATL job that can:
# Compress our CSV data line by line into parquet format
# Perform SQL operations that allow us to define tables which reflect our desired star schema
# Clean our data based on the data discovery performed above
# Load our processed data into a staging area of S3, so that it can be easily used by AWS RedShift.
#
# The ETL steps that we'll define to process our data can be accomplished used Glue Jobs.A seperate Glue Job will accomplish each step below:
# Define a program to crawl our raw S3 data and populate an AWS Glue Catalog with metadata
# Perform data transformations
#
# Its import to note that our csv data needs to be UTF-8 encoded for Glue to work properly.
#
# This architecture requires the following resources and configuration:
# - A routing table to store the network paths to various locations.
# - A VPC Gateway that gives access to outside networks and resources like S3 which lives outside our VPC.
# - A S3 Gateway Endpoint that allows S3 traffic from your Glue Jobs into your S3 buckets.
# - Buckets are storage locations within AWS, these will all exist outside of the VPC that we set up.
# - An AWS Glue Data Catalog to persist table metadata
#
#
# Steps will include:
# - Create a role that can access S3 and other services
# - Create an access policy for AWS Glue
# - Create a database to house our tables
# - Create tables for each data source
# - Use our S3 bucket as a data source
# - Set up network access to data stores

# %% [markdown]
# ### Create an AIM Role that has priveleges to access S3 and other services, which can be assumed by AWS Glue.

# %%
try:
    iam.create_role(
    Path="/",
    RoleName=GLUE_ROLE_NAME,
    AssumeRolePolicyDocument=json.dumps({
        "Version":"2012-10-17",
        "Statement":[{
            "Effect":"Allow",
            "Principal":{
                "Service":["glue.amazonaws.com"]},
            "Action":["sts:AssumeRole"]}]}),
    Description='Allow glue service to assume role to access other services')
except Exception as e:
    logging.error(e)
    print(e)
print (True)
# Out:
# True

# %% [markdown]
# ### Create an Access Policy for the newly created glue role, which grants permissions to list all bucket objects and perform all S3 Object-based actions on the bucket's content.
#
# https://boto3.amazonaws.com/v1/documentation/api/latest/reference/services/iam.html#IAM.Client.put_role_policy

# %%
try: 
    response = iam.put_role_policy(
        RoleName=GLUE_ROLE_NAME,
        PolicyName="S3Access",
        PolicyDocument=json.dumps({
            "Version": "2012-10-17",
            "Statement":[
                {
                    "Sid": "ListBucketObjects",
                    "Effect": "Allow",
                    "Action":["s3:ListBucket"],
                    "Resource": ["arn:aws:s3:::productdatauseast1"]
                },
                {
                    "Sid": "AllObjectActions",
                    "Effect": "Allow",
                    "Action":["s3:*Object"],
                    "Resource": ["arn:aws:s3:::productdatauseast1/*"]
                }
            ]
        })
    )
except Exception as e:
    logging.error(e)
    print(e)
print (True)
# Out:
# True

# %% [markdown]
# ### Add another AIM Policy to the glue role using the aim put-role-policy method. This glue access policy will enable glue to perform the following tasks:
#
# A description of the permissions granted by this policy can be found here: https://docs.aws.amazon.com/glue/latest/dg/create-service-policy.html

# %%
try: 
    response = iam.put_role_policy(
        RoleName=GLUE_ROLE_NAME,
        PolicyName="S3Access",
        PolicyDocument=json.dumps({
            "Version": "2012-10-17",
            "Statement": [
                {
                    "Effect": "Allow",
                    "Action": [
                        "glue:*",
                        "s3:GetBucketLocation",
                        "s3:ListBucket",
                        "s3:ListAllMyBuckets",
                        "s3:GetBucketAcl",
                        "ec2:DescribeVpcEndpoints",
                        "ec2:DescribeRouteTables",
                        "ec2:CreateNetworkInterface",
                        "ec2:DeleteNetworkInterface",
                        "ec2:DescribeNetworkInterfaces",
                        "ec2:DescribeSecurityGroups",
                        "ec2:DescribeSubnets",
                        "ec2:DescribeVpcAttribute",
                        "iam:ListRolePolicies",
                        "iam:GetRole",
                        "iam:GetRolePolicy",
                        "cloudwatch:PutMetricData"                
                    ],
                    "Resource": [
                        "*"
                    ]
                },
                {
                    "Effect": "Allow",
                    "Action": [
                        "s3:CreateBucket",
                        "s3:PutBucketPublicAccessBlock"
                    ],
                    "Resource": [
                        "arn:aws:s3:::aws-glue-*"
                    ]
                },
                {
                    "Effect": "Allow",
                    "Action": [
                        "s3:GetObject",
                        "s3:PutObject",
                        "s3:DeleteObject"
                    ],
                    "Resource": [
                        "arn:aws:s3:::aws-glue-*/*",
                        "arn:aws:s3:::*/*aws-glue-*/*"
                    ]
                },
                {
                    "Effect": "Allow",
                    "Action": [
                        "s3:GetObject"
                    ],
                    "Resource": [
                        "arn:aws:s3:::crawler-public*",
                        "arn:aws:s3:::aws-glue-*"
                    ]
                },
                {
                    "Effect": "Allow",
                    "Action": [
                        "logs:CreateLogGroup",
                        "logs:CreateLogStream",
                        "logs:PutLogEvents",
                        "logs:AssociateKmsKey"                
                    ],
                    "Resource": [
                        "arn:aws:logs:*:*:/aws-glue/*"
                    ]
                },
                {
                    "Effect": "Allow",
                    "Action": [
                        "ec2:CreateTags",
                        "ec2:DeleteTags"
                    ],
                    "Condition": {
                        "ForAllValues:StringEquals": {
                            "aws:TagKeys": [
                                "aws-glue-service-resource"
                            ]
                        }
                    },
                    "Resource": [
                        "arn:aws:ec2:*:*:network-interface/*",
                        "arn:aws:ec2:*:*:security-group/*",
                        "arn:aws:ec2:*:*:instance/*"
                    ]
                }
            ]
        }))
except Exception as e:
    logging.error(e)
    print(e)
print (True)
# Out:
# True

# %% [markdown]
# ## Create a database to house our tables using boto3

# %%
glueClient = boto3.client('glue')

# %%
try: 
    res = glueClient.create_database(
        DatabaseInput={
            'Name': GLUE_DB_NAME 
        })
except Exception as e:
    logging.error(e)
    print(e)
print (True)
# Out:
# ERROR:root:An error occurred (AlreadyExistsException) when calling the CreateDatabase operation: Database already exists.
# An error occurred (AlreadyExistsException) when calling the CreateDatabase operation: Database already exists.
# True

# %% [markdown]
# ## Create database tables for each data source, and associate them with our database to create and populate an AWS Glue Data Catalog.
#
# Table API docs: https://docs.aws.amazon.com/glue/latest/dg/aws-glue-api-catalog-tables.html#aws-glue-api-catalog-tables-StorageDescriptor
#
# Table data types: https://docs.aws.amazon.com/databrew/latest/dg/datatypes.html

# %%
try: 
    response = glueClient.create_table(
        DatabaseName=GLUE_DB_NAME,
        TableInput={
            'Name': 'aisles',
            'StorageDescriptor': {
              'Columns': [{
                'Name': 'aisle_id',
                'Type': 'integer'
              }, {
                'Name': 'aisle',
                'Type': 'string'
              }],
              'Location': 's3://crawler-public-us-west-2/flight/2016/csv',
              'InputFormat': 'org.apache.hadoop.mapred.TextInputFormat',
              'OutputFormat': 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat',
              'Compressed': False,
              'NumberOfBuckets': -1,
              'SerdeInfo': {
                'SerializationLibrary': 'org.apache.hadoop.hive.serde2.lazy.LazySimpleSerDe',
                'Parameters': {
                  'field.delim': ',',
                  'serialization.format': ','
                }
              },
            },
            'PartitionKeys': [{
              'Name': 'mon',
              'Type': 'string'
            }],
            'TableType': 'EXTERNAL_TABLE',
            'Parameters': {
              'EXTERNAL': 'TRUE',
              'classification': 'csv',
              'columnsOrdered': 'true',
              'compressionType': 'none',
              'delimiter': ',',
              'skip.header.line.count': '1',
              'typeOfData': 'file'
            }
            }
        ) 
except Exception as e:
    logging.error(e)
    print(e)
print (True)

# %% [markdown]
# # Create an identity-base IAM role policy granting Redshift ReadOnly premissions on our S3 reource.
#
# A crucial step in our data pipeline requires the movement of data from S3, our source storage database, to Redshift. To accomodate this step, we'll create an IAM Role that allows Redshift "ReadOnly" access to our S3 bucket so that data can be retrieved. This is nessecary because S3 is a blob storage service without functionality allowing it to write files to a different system or service.
#
# To create the policy, we'll need to:
# - Create a function `get_user_arns` that allows us to retieve all user ARNs from our account. This will be used to ensure we are creating a new user meeting AWS's unique identity naming constraints. It will also be used to get the ARN of new role that we will create.
# - Create a new IAM role using aim_client.create_role()
# - Attach a policy using aim_client.attach_role_policy()
# - Get the ARN for a role using aim_client.get_role()

# %% [markdown]
# ### Create a function that retrieves user ARNs
#
# Before we create a new role, we want to ensure that our new role has a unique name. It's a good practice to review previously created role, and remove any that are no longer being used to accodate existing quotas.

# %%
iam = boto3.client('iam', region_name=DEFAULT_REGION, 
                  aws_access_key_id=KEY, 
                  aws_secret_access_key=SECRET)

def get_user_arns(iam_client):
    paginator = iam_client.get_paginator('list_users')
    for response in paginator.paginate():
        for user in response.get("Users"):
            print(user['Arn'])
            
get_user_arns(iam)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[210], line 1
# ----> 1 iam = boto3.client('iam', region_name=DEFAULT_REGION,
#       2                   aws_access_key_id=KEY,
#       3                   aws_secret_access_key=SECRET)
#       5 def get_user_arns(iam_client):
#       6     paginator = iam_client.get_paginator('list_users')
#
# NameError: name 'boto3' is not defined

# %% [markdown]
# ### Create a new IAM Role
# The Request Syntax for creating a new role via API is as shown below. API documentation explaining each parameter can be found here: https://docs.aws.amazon.com/IAM/latest/APIReference/API_CreateRole.html. It should be noted that the `AssumeRolePolicyDocument` needs to be passed in as a json string, which can be done using `json.dumps()`. Here, the purpose of the new role is to assume the role of our root user, who can access other AWS services.
#
# ```
#
# response = client.create_role(
#     Path='string',
#     RoleName='string',
#     AssumeRolePolicyDocument=json.dumps({
#         "Version":"2012-10-17",
#         "Statement":[{
#             "Effect":["Allow"| "Deny"],
#             "Principal":{
#                 "Service":["<service_name>.amazonaws.com"]},
#             "Action":[<Action>]}]}),
#     Description='string',
#     MaxSessionDuration=123,
#     PermissionsBoundary='string',
#     Tags=[
#         {
#             'Key': 'string',
#             'Value': 'string'
#         },
#     ]
# )
# ```

# %%
try:
    iam.create_role(
    Path="/",
    RoleName=IAM_ROLE_NAME,
    AssumeRolePolicyDocument=json.dumps({
        "Version":"2012-10-17",
        "Statement":[{
            "Effect":"Allow",
            "Principal":{
                "Service":["redshift.amazonaws.com"]},
            "Action":["sts:AssumeRole"]}]}),
    Description='Allow redshift cluster to assume role to access other services')
except Exception as e:
    logging.error(e)
    print(e)
print (True)
# Out:
# ERROR:root:An error occurred (EntityAlreadyExists) when calling the CreateRole operation: Role with name dwhAdmin already exists.
# An error occurred (EntityAlreadyExists) when calling the CreateRole operation: Role with name dwhAdmin already exists.
# True

# %% [markdown]
# ### Attach a S3READONLY Policy to IAM ROLE
#
# Instead of creating a read only access policy from scratch, we can use the AWS managed policy `AmazonS3ReadOnlyAccess` to ensure our redshift cluster can only read files from S3.

# %%
try:
    response = iam.attach_role_policy(
        RoleName=IAM_ROLE_NAME,
        PolicyArn='arn:aws:iam::aws:policy/AmazonS3ReadOnlyAccess')
except Exception as e:
    logging.error(e)
    print(e)
print (True)
# Out:
# True

# %% [markdown]
# ### Get the ARN for our New IAM Role

# %%
response = iam.get_role(
    RoleName=IAM_ROLE_NAME
)
ROLE_ARN = response['Role']['Arn']

# %% [markdown]
# # Create a Redshift Cluster
#
# Now that we have created an S3 bucket, with permissions, added data file to it, and created a IAM role with an ability to take actions on S3 we will create a redshift cluster. Recall that we have already saved the following required variables to our configuration file.
#
#
# ```
# CLUSTER_TYPE = config.get("DWH", "CLUSTER_TYPE")
# NODE_CT = config.get("DWH", "NODE_CT")
# NODE_TYPE = config.get("DWH", "NODE_TYPE")
# IAM_ROLE_NAME = config.get("DWH", "IAM_ROLE_NAME")
# CLUSTER_ID = config.get("DWH", "CLUSTER_ID")
# DB = config.get("DWH", "DB")
# DB_USER = config.get("DWH", "DB_USER")
# DB_PASSWORD = config.get("DWH", "DB_PASSWORD")
# DB_PORT = config.get("DWH", "DB_PORT")
# ```
#
# The syntax for creating a new redshoft cluster can be found here: https://boto3.amazonaws.com/v1/documentation/api/latest/reference/services/redshift.html#Redshift.Client.create_cluster
